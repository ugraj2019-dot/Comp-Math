# %% [markdown]
# <a href="https://colab.research.google.com/github/ugraj2019-dot/Comp-Math/blob/main/Math_Workshop_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Ugraj Bhandari**
# #**2166957**

# %%
# Example 1
import numpy as np
import matplotlib.pyplot as plt
""" Part 1 - Problem 1: Solve linear systems graphically. """
# Generate 100 equidistant point between -5 to 5 for x
x = np.linspace(-5,5,100)
## Calculate y values for Equation 1 and 2
y1 = (5-x)/3
y2 = (5+x)/2
y3 = 3-x
## Generate a figure frame for plotting the lines
fig, ax = plt.subplots()
## Plot the two lines
ax.plot(x,y1, color='r')
ax.plot(x,y2, color='g')
ax.plot(x,y3, color='b')
## To decorate the plot, we insert equations.
ax.text(0.5,0.6, '$x+3y = 5$', color='r')
ax.text(-3,0.5,'$x-2y = -5$', color='g')
ax.text(1.2,2, '$x+y = 3$', color='b')
## Set the limits of the X & Y axes.
ax.set_xlim(-4,4)
ax.set_ylim(-2,6)
## Set property of X and Y axes, e.g., color and linewidth
ax.axvline(color='k',linewidth = 1)
ax.axhline(color='k',linewidth = 1)
## This option specifies the ticks based the list of numbers provided.
ax.set_xticks(list(range(-4,5)))
ax.set_aspect('equal')
ax.grid(True,ls=':')
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %%
# Task 1
import numpy as np
import matplotlib.pyplot as plt
# Generate 100 equidistant point between -5 to 5 for x
x = np.linspace(-5,5,100)
## Calculate y values for Equation 1 and 2
y1 = (3-2*x)/3
y2 = (6-4*x)/6
y3 = (3*x-1)/2
## Generate a figure frame for plotting the lines
fig, ax = plt.subplots()
## Plot the two lines
ax.plot(x,y1, color='r')
ax.plot(x,y2, color='g')
ax.plot(x,y3, color='b')
## To decorate the plot, we insert equations.
ax.text(0.5,0.6, '$x+3y = 5$', color='r')
ax.text(-3,0.5,'$x-2y = -5$', color='g')
ax.text(1.2,2, '$x+y = 3$', color='b')
## Set the limits of the X & Y axes.
ax.set_xlim(-4,4)
ax.set_ylim(-2,6)
## Set property of X and Y axes, e.g., color and linewidth
ax.axvline(color='k',linewidth = 1)
ax.axhline(color='k',linewidth = 1)
## This option specifies the ticks based the list of numbers provided.
ax.set_xticks(list(range(-4,5)))
ax.set_aspect('equal')
ax.grid(True,ls=':')
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %%
# Task 2 A
import numpy as np
A = np.random.randint(1,10,(5,6))
B = np.random.randint(1,10,(5,6))
C = A + B
print("Matrix A:\n", A)
print("Matrix B:\n", B)
print("Result (A+B):\n", C)
# Out:
# Matrix A:
#  [[3 9 4 8 4 7]
#  [5 1 5 7 3 4]
#  [7 7 5 9 3 2]
#  [1 6 3 7 9 8]
#  [9 6 6 5 7 1]]
# Matrix B:
#  [[5 2 6 8 4 4]
#  [9 7 6 6 5 6]
#  [1 4 1 4 5 7]
#  [5 2 5 9 4 4]
#  [3 3 8 8 1 6]]
# Result (A+B):
#  [[ 8 11 10 16  8 11]
#  [14  8 11 13  8 10]
#  [ 8 11  6 13  8  9]
#  [ 6  8  8 16 13 12]
#  [12  9 14 13  8  7]]

# %%
# Task 2 B
A = np.random.randint(1,10,(2,3))
B = np.random.randint(1,10,(2,3))
C = np.random.randint(1,10,(2,3))
result = A - B + C
print(A, B, C, result)
# Out:
# [[7 6 6]
#  [2 1 4]] [[8 4 5]
#  [4 5 2]] [[7 3 2]
#  [4 3 4]] [[ 6  5  3]
#  [ 2 -1  6]]

# %%
# Task C
A = np.random.randint(1,21,(4,4))
print(A)
num = int(input("Enter number: "))
count = np.sum(A == num)
if count > 0:
    print("Found", count, "times")
else:
    print("Not found")
# Out:
# [[ 3 13  9 12]
#  [13 13  7 14]
#  [ 2 17 16  8]
#  [12 19  6  3]]
# Enter number: 6
# Found 1 times

# %%
import numpy as np
a = np.array([[1, 2], [3, 4]])
det = np.linalg.det(a)
print("Determinant:", det)
# Out:
# Determinant: -2.0000000000000004

# %%
rank = np.linalg.matrix_rank(a)
print("Rank:", rank)
# Out:
# Rank: 2

# %%
inv = np.linalg.inv(a)
print("Inverse:\n", inv)
# Out:
# Inverse:
#  [[-2.   1. ]
#  [ 1.5 -0.5]]

# %%
b = np.array([1, 2])
x = np.linalg.solve(a, b)
print("Solution:", x)
# Out:
# Solution: [0.  0.5]

# %%
import numpy as np
a = np.random.randn(3, 2)
b = np.linalg.pinv(a)
result = np.allclose(a, np.dot(a, np.dot(b, a)))
print("Check A A+ A = A:", result)
# Out:
# Check A A+ A = A: True

# %%
#Task 3 A
import numpy as np
A = np.random.randint(1, 20, (5, 5))
print("Matrix A:\n", A)
rank = np.linalg.matrix_rank(A)
print("Rank of A:", rank)
det = np.linalg.det(A)
print("Determinant of A:", det)
if rank == 5 and det != 0:
    print("Matrix is invertible")
else:
    print("Matrix is NOT invertible")
# Out:
# Matrix A:
#  [[17  5 16  2  3]
#  [12 14  7  9  3]
#  [ 4  7  3  6 12]
#  [10 15  3 19  1]
#  [18 17  3 17 14]]
# Rank of A: 5
# Determinant of A: 177904.99999999997
# Matrix is invertible

# %%
#Task 3 B
A = np.random.rand(5,5)
x = np.random.rand(5)
b = np.dot(A, x)
x_sol = np.linalg.solve(A, b)
print(x_sol)
# Out:
# [0.7094485  0.72462709 0.81363777 0.49431223 0.15087838]

# %%
#Task 3 C
import numpy as np
A = np.array([
    [8, 3, -2],
    [-4, 7, 5],
    [3, 4, -12]
])
b = np.array([9, 15, 35])
x = np.linalg.solve(A, b)
print("Solution:", x)
# Out:
# Solution: [-0.58226371  3.22870478 -1.98599767]

# %%
#Task 4
import numpy as np
import matplotlib.pyplot as plt
x = np.array([3,2,1,0,1,2,3,4,5,7])
y = np.array([7.6,1,4.8,5,2.8,0.6,4,6.2,6,6.4])
coeffs = np.polyfit(x, y, 2)
poly = np.poly1d(coeffs)
x_line = np.linspace(min(x), max(x), 100)
y_line = poly(x_line)
plt.scatter(x, y)
plt.plot(x_line, y_line)
plt.xlabel("X")
plt.ylabel("Y")
plt.grid()
plt.show()
print("Polynomial:", poly)
# Out:
# Polynomial:          2
# 0.06667 x + 0.06667 x + 3.467
